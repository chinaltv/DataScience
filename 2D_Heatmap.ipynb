# %% [markdown]
# 该脚本已完善。可用于制作单个被试拼图游戏的注视点热图。其中，
# 结果需求：
# 1. 生成整个流程的注视点热图 √
# 2. 生成第一次对话时间内的注视点热图 √
# 3. 生成最后一次对话时间内的注视点热图 √
#
# 注：
# - 原始数据可能需要去除不在背景图范围内的注视点坐标 √
# - 热图的尺寸、dpi需要调整到合适大小 √
# - 单个被试注视点热图处理完后需进阶批量处理（移步batch_json_2Dhm/batch_json_2Dhm_fl函数）

# %%
import os
from ASD_utilities import read_one, json_2Dhm, json_2Dhm_fl


# 如果你用了下面两行，请注意不要重复点击运行，得清空内存重新运行才能加载新的图。如果不用，即清空以下import+%...，则（在vscode内）不能自由缩放，但可以重复运行生成图。
import ipympl
# %matplotlib widget 




os.chdir('e:/Dept_Sci_Res/asd/01_Data/01预实验数据')
background_filepath = './背景图/house1.jpg'
ts_filepath = './2022_09_19_13_1136_拼图游戏_振友/_1136_304816_PPGamePlayRecord.json'
json_filepath = './2022_09_19_13_1136_拼图游戏_振友/A8.json'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 12
#       6 import ipympl
#       7 get_ipython().run_line_magic('matplotlib', 'widget')
# ---> 12 os.chdir('e:/Dept_Sci_Res/asd/01_Data/01预实验数据')
#      13 background_filepath = './背景图/house1.jpg'
#      14 ts_filepath = './2022_09_19_13_1136_拼图游戏_振友/_1136_304816_PPGamePlayRecord.json'
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: 'e:/Dept_Sci_Res/asd/01_Data/01预实验数据'

# %%
json_2Dhm(json_filepath, background_filepath)

# %%
json_2Dhm_fl(json_filepath, ts_filepath, background_filepath)
