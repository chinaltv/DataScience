# %%
import os
import numpy as np
import pandas as pd
import mne
import scipy.signal
from scipy.signal import get_window
from sleep_utilities import art_clean, generate_features, art_clean_NE_single
from mne.time_frequency import psd_array_welch
os.chdir('e:/SDODT Co., Ltd/Sleep issues/data/test')

InputPaths = "./02.txt"

# %%
raw = np.loadtxt(InputPaths, dtype = np.floating, delimiter = ',') # 读取文件
raw
# Out:
# array([8774330., 8774241., 8774182., ..., 8363742., 8363891., 8364061.])

# %%
# fs = 250; window = 256; noverlap = 96; nfft = 512;

# psd1, freq1 = mne.time_frequency.psd_array_welch(raw, sfreq = 250, n_fft = 512, n_overlap = 96, window = get_window(window = 'hamming', Nx = 256), n_per_seg= 256)
freq2, psd2 = scipy.signal.welch(raw, fs = 250, noverlap = None, nfft = 512, window = get_window(window = 'hamming', Nx = 256), nperseg = 256, detrend=False)
# Out:
# Effective window size : 2.048 (s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished

# %%
# print(psd1)
# print(freq1)
window = get_window(window = 'hamming', Nx = 256)
window
# Out:
# array([0.08      , 0.08013854, 0.08055409, 0.08124639, 0.08221503,
#        0.08345941, 0.08497881, 0.08677228, 0.08883877, 0.09117702,
#        0.09378562, 0.09666301, 0.09980745, 0.10321704, 0.10688973,
#        0.11082331, 0.11501542, 0.11946351, 0.12416493, 0.12911682,
#        0.13431622, 0.13975998, 0.14544484, 0.15136736, 0.15752398,
#        0.16391099, 0.17052454, 0.17736064, 0.18441519, 0.19168393,
#        0.19916248, 0.20684634, 0.21473088, 0.22281135, 0.23108288,
#        0.23954049, 0.24817909, 0.25699347, 0.26597832, 0.27512823,
#        0.28443769, 0.29390109, 0.30351274, 0.31326683, 0.3231575 ,
#        0.33317879, 0.34332466, 0.353589  , 0.36396562, 0.37444828,
#        0.38503067, 0.3957064 , 0.40646905, 0.41731213, 0.42822912,
#        0.43921343, 0.45025845, 0.46135753, 0.47250398, 0.48369109,
#        0.49491212, 0.5061603 , 0.51742887, 0.52871103, 0.54      ,
#        0.55128897, 0.56257113, 0.5738397 , 0.58508788, 0.59630891,
# ...

# %%
print(psd2)
# Out:
# [5.40795165e+13 7.22634569e+13 1.96214676e+13 1.38554227e+12
#  1.95489174e+05 3.87556147e+08 6.48055215e+04 4.71649682e+09
#  3.15462258e+04 5.86168432e+09 1.71309541e+04 5.14899594e+09
#  1.11233861e+04 4.23154330e+09 8.26518679e+03 3.44691998e+09
#  5.65527732e+03 2.82749490e+09 4.33608172e+03 2.34638268e+09
#  3.70075076e+03 1.97143724e+09 2.65857210e+03 1.67597261e+09
#  2.21679632e+03 1.44045278e+09 1.85632354e+03 1.25027257e+09
#  1.56252533e+03 1.09475496e+09 1.29712181e+03 9.66355792e+08
#  1.15007559e+03 8.59100518e+08 1.01886359e+03 7.68680864e+08
#  8.68640987e+02 6.91904366e+08 8.34377445e+02 6.26093456e+08
#  7.46692720e+02 5.69318463e+08 6.70440833e+02 5.19980995e+08
#  6.54054192e+02 4.76883231e+08 5.57249820e+02 4.39040083e+08
#  5.49966623e+02 4.05574719e+08 5.12343976e+02 3.75902135e+08
#  4.68640802e+02 3.49443524e+08 4.35901607e+02 3.25767263e+08
#  4.20620341e+02 3.04488727e+08 4.00112561e+02 2.85296229e+08
# ...
